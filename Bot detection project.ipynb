# %% [markdown]
# My project was based off a kaggle competition. The aim is to identify computer generated bidding bots on an online auction website. Removal of these bots would prevent unfair auction activity. The data was completely provided by kaggle. The performance measure would be the score returned by kaggle on submission of the testing data outcomes. The ideal outcomes will never be shown.

# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
# %matplotlib inline

# %% [markdown]
# Get the data. Bid data has all the bids made by the users. The training data has the bidder IDs, the outcome(whether the particular ID was found to be a bot or not), the payment and address. The payment and address are scrambled. The testing data has all the same columns as the training data but no outcomes. The outcomes are to be predicted and given to kaggle to be evaluated. We cannot see the ideal outcome.

# %%
bid_data=pd.read_csv('ml_project_data/bids.csv')
training_data=pd.read_csv('ml_project_data/train.csv')
testing_data=pd.read_csv('ml_project_data/test.csv')

# %%
bid_data.head()
# Out:
#    bid_id                              bidder_id auction merchandise  device  \
# 0       0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr     jewelry  phone0
# 1       1  668d393e858e8126275433046bbd35c6tywop   aeqok   furniture  phone1
# 2       2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e  home goods  phone2
# 3       3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix     jewelry  phone4
# 4       4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix     jewelry  phone5
#
#                time country              ip              url
# 0  9759243157894736      us   69.166.231.58  vasstdc27m7nks3
# 1  9759243157894736      in   50.201.125.84  jmqlhflrzwuay9c
# 2  9759243157894736      py  112.54.208.157  vasstdc27m7nks3
# 3  9759243157894736      in   18.99.175.133  vasstdc27m7nks3
# 4  9759243157894736      in    145.138.5.37  vasstdc27m7nks3

# %%
bid_data.shape
# Out:
# (7656334, 9)

# %%
training_data.head()
# Out:
#                                bidder_id  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1  624f258b49e77713fc34034560f93fb3hu3jo
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj
# 3  4bee9aba2abda51bf43d639013d6efe12iycd
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228754av
# 1  a3d2de7675556553a5f08e4c88d2c228v1sga
# 2  a3d2de7675556553a5f08e4c88d2c2280cybl
# 3  51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4  a3d2de7675556553a5f08e4c88d2c22857ddh
#
#                                  address  outcome
# 0  a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0
# 1  ae87054e5a97a8f840a3991d12611fdcrfbq3      0.0
# 2  92520288b50f03907041887884ba49c0cl0pd      0.0
# 3  4cb9717c8ad7e88a9a284989dd79b98dbevyi      0.0
# 4  2a96c3ce94b3be921e0296097b88b56a7x1ji      0.0

# %%
training_data.shape
# Out:
# (2013, 4)

# %%
testing_data.head()
# Out:
#                                bidder_id  \
# 0  49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1  a921612b85a1494456e74c09393ccb65ylp4y
# 2  6b601e72a4d264dab9ace9d7b229b47479v6i
# 3  eaf0ed0afc9689779417274b4791726cn5udi
# 4  cdecd8d02ed8c6037e38042c7745f688mx5sf
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228htx90
# 1  a3d2de7675556553a5f08e4c88d2c228rs17i
# 2  925381cce086b8cc9594eee1c77edf665zjpl
# 3  a3d2de7675556553a5f08e4c88d2c228nclv5
# 4  a3d2de7675556553a5f08e4c88d2c228dtdkd
#
#                                  address
# 0  5d9fa1b71f992e7c7a106ce4b07a0a754le7c
# 1  a3d2de7675556553a5f08e4c88d2c228klidn
# 2  a3d2de7675556553a5f08e4c88d2c228aght0
# 3  b5714de1fd69d4a0d2e39d59e53fe9e15vwat
# 4  c3b363a3c3b838d58c85acf0fc9964cb4pnfa

# %%
testing_data.shape
# Out:
# (4700, 3)

# %% [markdown]
# The values in the bid data need to be sorted by the bidder_id and time to make it easier to work with.

# %%
bid_data=bid_data.sort_values(by=['bidder_id','time'],ascending=[True,True])
bid_data.head()
# Out:
#           bid_id                              bidder_id auction merchandise  \
# 7179832  7179832  001068c415025a009fee375a12cff4fcnht8y   4ifac     jewelry
# 1281292  1281292  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 1281311  1281311  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 6805028  6805028  0030a2dd87ad2733e0873062e4f83954mkj86   obbny      mobile
# 3967330  3967330  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   obbny      mobile
#
#            device              time country               ip              url
# 7179832  phone561  9706345052631578      bn  139.226.147.115  vasstdc27m7nks3
# 1281292  phone640  9766744105263157      sg    37.40.254.131  vasstdc27m7nks3
# 1281311  phone219  9766744210526315      sg    37.40.254.131  vasstdc27m7nks3
# 6805028  phone313  9704553947368421      ir     21.67.17.162  vnw40k8zzokijsv
# 3967330  phone420  9640018631578947      id     44.241.8.179  sj4jidex850loas

# %% [markdown]
# The amount of time between bids done by the same bidder are calculated. I figured this will be useful as bots will be able to click much faster than humans.

# %%
time_difference=bid_data.groupby('bidder_id')['time'].diff()
bid_data['time_difference']=time_difference
bid_data.head()
# Out:
#           bid_id                              bidder_id auction merchandise  \
# 7179832  7179832  001068c415025a009fee375a12cff4fcnht8y   4ifac     jewelry
# 1281292  1281292  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 1281311  1281311  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 6805028  6805028  0030a2dd87ad2733e0873062e4f83954mkj86   obbny      mobile
# 3967330  3967330  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   obbny      mobile
#
#            device              time country               ip              url  \
# 7179832  phone561  9706345052631578      bn  139.226.147.115  vasstdc27m7nks3
# 1281292  phone640  9766744105263157      sg    37.40.254.131  vasstdc27m7nks3
# 1281311  phone219  9766744210526315      sg    37.40.254.131  vasstdc27m7nks3
# 6805028  phone313  9704553947368421      ir     21.67.17.162  vnw40k8zzokijsv
# 3967330  phone420  9640018631578947      id     44.241.8.179  sj4jidex850loas
#
#          time_difference
# 7179832              NaN
# 1281292              NaN
# 1281311      105263158.0
# 6805028              NaN
# 3967330              NaN

# %% [markdown]
# This is to create a dataframe with the details of all the bidders

# %%
bidder_data=pd.DataFrame(data=bid_data['bidder_id'].unique(),columns=['bidder_id'],index=bid_data['bidder_id'].unique())
bidder_data.head()
# Out:
#                                                                    bidder_id
# 001068c415025a009fee375a12cff4fcnht8y  001068c415025a009fee375a12cff4fcnht8y
# 002d229ffb247009810828f648afc2ef593rb  002d229ffb247009810828f648afc2ef593rb
# 0030a2dd87ad2733e0873062e4f83954mkj86  0030a2dd87ad2733e0873062e4f83954mkj86
# 003180b29c6a5f8f1d84a6b7b6f7be57tjj1o  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o
# 00486a11dff552c4bd7696265724ff81yeo9v  00486a11dff552c4bd7696265724ff81yeo9v

# %%
bidder_data.shape #6614 users have made bids
# Out:
# (6614, 1)

# %% [markdown]
# I figured that bots would be making way more bids than humans. This is to calculate the number of bids made by each bidder.

# %%
bid_counts_by_id=bid_data.groupby('bidder_id')['bidder_id'].agg('count')
bidder_data['no_of_bids_made']=bid_counts_by_id
bidder_data.head(20)
# Out:
#                                                                    bidder_id  \
# 001068c415025a009fee375a12cff4fcnht8y  001068c415025a009fee375a12cff4fcnht8y
# 002d229ffb247009810828f648afc2ef593rb  002d229ffb247009810828f648afc2ef593rb
# 0030a2dd87ad2733e0873062e4f83954mkj86  0030a2dd87ad2733e0873062e4f83954mkj86
# 003180b29c6a5f8f1d84a6b7b6f7be57tjj1o  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o
# 00486a11dff552c4bd7696265724ff81yeo9v  00486a11dff552c4bd7696265724ff81yeo9v
# 0051aef3fdeacdadba664b9b3b07e04e4coc6  0051aef3fdeacdadba664b9b3b07e04e4coc6
# 0053b78cde37c4384a20d2da9aa4272aym4pb  0053b78cde37c4384a20d2da9aa4272aym4pb
# 0061edfc5b07ff3d70d693883a38d370oy4fs  0061edfc5b07ff3d70d693883a38d370oy4fs
# 00862324eb508ca5202b6d4e5f1a80fc3t3lp  00862324eb508ca5202b6d4e5f1a80fc3t3lp
# 009479273c288b1dd096dc3087653499lrx3c  009479273c288b1dd096dc3087653499lrx3c
# 009cee781e8414f7fb55b2f92157e9dbu0y6o  009cee781e8414f7fb55b2f92157e9dbu0y6o
# 00a0517965f18610417ee784a05f494d4dw6e  00a0517965f18610417ee784a05f494d4dw6e
# 00a79ebd15f0b24a0a3b5794457cd8ed7dng1  00a79ebd15f0b24a0a3b5794457cd8ed7dng1
# 00b519ec8ed5e370328451379bb708a306eoj  00b519ec8ed5e370328451379bb708a306eoj
# 00cc97158e6f4cb8eac3c0075918b7ffi5k8o  00cc97158e6f4cb8eac3c0075918b7ffi5k8o
# 00ceb1b66fc6c08f2e1b7937b5bc7f870qn5k  00ceb1b66fc6c08f2e1b7937b5bc7f870qn5k
# 00dd948c3a88f7b68f1952dbeeac68ffb6qoc  00dd948c3a88f7b68f1952dbeeac68ffb6qoc
# 00e0f614d9dd32dd27f6080f472d2934emlos  00e0f614d9dd32dd27f6080f472d2934emlos
# 01067975436d123f717ee5aba0dd4bbfa0937  01067975436d123f717ee5aba0dd4bbfa0937
# 010e5ed5eb439e0daf1870a0b426e32cztbdt  010e5ed5eb439e0daf1870a0b426e32cztbdt
#
#                                        no_of_bids_made
# 001068c415025a009fee375a12cff4fcnht8y                1
# 002d229ffb247009810828f648afc2ef593rb                2
# 0030a2dd87ad2733e0873062e4f83954mkj86                1
# 003180b29c6a5f8f1d84a6b7b6f7be57tjj1o                3
# 00486a11dff552c4bd7696265724ff81yeo9v               20
# 0051aef3fdeacdadba664b9b3b07e04e4coc6               68
# 0053b78cde37c4384a20d2da9aa4272aym4pb            10939
# 0061edfc5b07ff3d70d693883a38d370oy4fs              134
# 00862324eb508ca5202b6d4e5f1a80fc3t3lp                5
# 009479273c288b1dd096dc3087653499lrx3c                1
# 009cee781e8414f7fb55b2f92157e9dbu0y6o                5
# 00a0517965f18610417ee784a05f494d4dw6e              141
# 00a79ebd15f0b24a0a3b5794457cd8ed7dng1              398
# 00b519ec8ed5e370328451379bb708a306eoj             1067
# 00cc97158e6f4cb8eac3c0075918b7ffi5k8o                3
# 00ceb1b66fc6c08f2e1b7937b5bc7f870qn5k               80
# 00dd948c3a88f7b68f1952dbeeac68ffb6qoc                1
# 00e0f614d9dd32dd27f6080f472d2934emlos             2072
# 01067975436d123f717ee5aba0dd4bbfa0937              543
# 010e5ed5eb439e0daf1870a0b426e32cztbdt               42

# %% [markdown]
# This is to get each bidders country

# %%
temp=bid_data.groupby('bidder_id')['bidder_id','country'].head()
temp=temp.drop_duplicates('bidder_id')
bidder_data=bidder_data.merge(temp,on='bidder_id')
bidder_data.head()
# Out:
#                                bidder_id  no_of_bids_made country
# 0  001068c415025a009fee375a12cff4fcnht8y                1      bn
# 1  002d229ffb247009810828f648afc2ef593rb                2      sg
# 2  0030a2dd87ad2733e0873062e4f83954mkj86                1      ir
# 3  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o                3      id
# 4  00486a11dff552c4bd7696265724ff81yeo9v               20      ng

# %% [markdown]
# This is to get the sum of the time between each bid for individual users.

# %%
time_sums=bid_data.groupby(['bidder_id'])['time_difference'].sum()
time_sums=pd.DataFrame(data=time_sums)
bidder_data['sum_of_diffs']=list(time_sums['time_difference'])
bidder_data.head()
# Out:
#                                bidder_id  no_of_bids_made country  \
# 0  001068c415025a009fee375a12cff4fcnht8y                1      bn
# 1  002d229ffb247009810828f648afc2ef593rb                2      sg
# 2  0030a2dd87ad2733e0873062e4f83954mkj86                1      ir
# 3  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o                3      id
# 4  00486a11dff552c4bd7696265724ff81yeo9v               20      ng
#
#    sum_of_diffs
# 0           NaN
# 1  1.052632e+08
# 2           NaN
# 3  6.595568e+13
# 4  7.634984e+13

# %% [markdown]
# This is to get the mean time taken between bids

# %%
bidder_data['mean_time_diff']=bidder_data['sum_of_diffs']/bidder_data['no_of_bids_made']
bidder_data.head()
# Out:
#                                bidder_id  no_of_bids_made country  \
# 0  001068c415025a009fee375a12cff4fcnht8y                1      bn
# 1  002d229ffb247009810828f648afc2ef593rb                2      sg
# 2  0030a2dd87ad2733e0873062e4f83954mkj86                1      ir
# 3  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o                3      id
# 4  00486a11dff552c4bd7696265724ff81yeo9v               20      ng
#
#    sum_of_diffs  mean_time_diff
# 0           NaN             NaN
# 1  1.052632e+08    5.263158e+07
# 2           NaN             NaN
# 3  6.595568e+13    2.198523e+13
# 4  7.634984e+13    3.817492e+12

# %% [markdown]
# On exploration, I found that bids from countries id and in(Indonesia and India I assume) have a large portion of overall bots that were detected. I incorporated this feature that would tell me if they

# %%
bidder_data['id_or_in']=np.where(bidder_data['country']=='id',1,
                                  np.where(bidder_data['country']=='in',1,0))
bidder_data.head()
# Out:
#                                bidder_id  no_of_bids_made country  \
# 0  001068c415025a009fee375a12cff4fcnht8y                1      bn
# 1  002d229ffb247009810828f648afc2ef593rb                2      sg
# 2  0030a2dd87ad2733e0873062e4f83954mkj86                1      ir
# 3  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o                3      id
# 4  00486a11dff552c4bd7696265724ff81yeo9v               20      ng
#
#    sum_of_diffs  mean_time_diff  id_or_in
# 0           NaN             NaN         0
# 1  1.052632e+08    5.263158e+07         0
# 2           NaN             NaN         0
# 3  6.595568e+13    2.198523e+13         1
# 4  7.634984e+13    3.817492e+12         0

# %% [markdown]
# Merging the training data with the bidder data. There are a few bidders with no bids, hence the merge has to be a left join. This explains a few of the NaN values.

# %%
training_data=training_data.merge(bidder_data, how='left',on='bidder_id')

# %%
training_data.isnull().sum()
# Out:
# bidder_id            0
# payment_account      0
# address              0
# outcome              0
# no_of_bids_made     29
# country             35
# sum_of_diffs       331
# mean_time_diff     331
# id_or_in            29
# dtype: int64

# %%
training_data[training_data['no_of_bids_made']!=training_data['no_of_bids_made']]
# Out:
#                                   bidder_id  \
# 49    5f50c6187a179e2ee7ba2fbcfc845c7a1smgr
# 88    02bde521e763e4f4e590e8368149e04a96il9
# 175   dd661e2d6e79a5b3e66c82373d50f3ee86k85
# 236   908ce7060337fd8550760a100921f6f7wsemn
# 262   b64c209b3d1d91a663d134961af89125u0s9a
# 271   96b1df591dbbf3a002578574671d9ff1rmzev
# 299   d2138bce99f535c244dab68652ccfa2enshxk
# 305   c08e5e3325e2f4fea171f24ca018e675we8kj
# 339   187636e527504df29bf42d4a2b7767e54bgv7
# 364   74f153bd134afc92866a6bc5cceb2088120y0
# 620   4b3e6a8a52c413a32f76a6d7a84a54bb8gb0t
# 633   4d0d345f552877998f41ba3cd1ba299885vu5
# 741   59fe751fb6c277016b7ebe3609aa1b15vhg7w
# 750   d1780c224460a0c20d5c2f5f68714c5264xd0
# 773   dc9a7ebdb6fb8dd3267ac26dbe5a62b68e4vw
# 808   1e3642857c10e72cedaf7890e3c07bfa8ibzv
# 908   4444bfb455b90711234e0c25345abbaddrt0x
# 997   c62a6956e93ac3b56b1292f2c2d85b1fyekav
# 1026  1214fbf35079e7afc0a35645f8be8b218fd5o
# 1052  f9378eb3e522beef7e6a4e1f275bbe0eaboro
# 1135  977436b0a445fa555d537fbf1d4bff2e4z40h
# 1149  7a3378ad9999b1fde0a4562a9b036f038cdal
# 1304  3de66f8a5453943040d42e1e73f11eebll8h9
# 1496  c8cf68aa6abce25325dfdad4a98fd890ap57f
# 1511  a4475cf8808f8951dd5163ded3ee8032g9vxd
# 1551  db12e9cad5e847cd7a40ec1ee649e475iwzqo
# 1633  40fafe756c4695b32df7d19d4c710dabvzr79
# 1729  583ce05b5add00d9e7e5dcefb3c436f26d7c2
# 1909  4fcdd880c4e1a1767c4d26f74bb3466f11osj
#
#                             payment_account  \
# 49    7326f0a1592b18cb1e6ed7c8ebbd03a72qf7p
# 88    a3d2de7675556553a5f08e4c88d2c2286r1lb
# 175   e805bf9d2399ddc37a194e04703a333c7bv82
# 236   a3d2de7675556553a5f08e4c88d2c2282yldz
# 262   f7558102989f5665bbbea00358f8434adf9o9
# 271   a3d2de7675556553a5f08e4c88d2c2288tx3v
# 299   72a51aa2faf94e7ffdf736fdb389d4efpyojt
# 305   efd15ad70741e38f212ac919ca569615r3g33
# 339   a3d2de7675556553a5f08e4c88d2c2281swzb
# 364   a3d2de7675556553a5f08e4c88d2c228fd0s8
# 620   ef57fc6d955628b73e7b49927b3a9a92smhs1
# 633   a3d2de7675556553a5f08e4c88d2c2287qzaj
# 741   a3d2de7675556553a5f08e4c88d2c228uszco
# 750   a3d2de7675556553a5f08e4c88d2c228isxlr
# 773   bde1355fc6c862b13f039caf3f956541h3cbo
# 808   a3d2de7675556553a5f08e4c88d2c228hydky
# 908   1b223b8687ec3408c7cd13c1582e5cf89m6r9
# 997   a3d2de7675556553a5f08e4c88d2c228vak14
# 1026  1125b4a1f6328a4e97de0fcee423c5c87vg6o
# 1052  a3d2de7675556553a5f08e4c88d2c2285ew0e
# 1135  a3d2de7675556553a5f08e4c88d2c228dbc6k
# 1149  a3d2de7675556553a5f08e4c88d2c228xb0m4
# 1304  a3d2de7675556553a5f08e4c88d2c2287c9l0
# 1496  a3d2de7675556553a5f08e4c88d2c228yinlc
# 1511  a3d2de7675556553a5f08e4c88d2c2288r2dg
# 1551  30a9f295085433ca3a1a3cea9b644d24ytevw
# 1633  0db78cbafef79ad159f93d913aafe769b7j2b
# 1729  a3d2de7675556553a5f08e4c88d2c2283q3p6
# 1909  a3d2de7675556553a5f08e4c88d2c228ma0xs
#
#                                     address  outcome  no_of_bids_made country  \
# 49    a3d2de7675556553a5f08e4c88d2c228uaoqg      0.0              NaN     NaN
# 88    935d2083173e96f099816c1b1f7ee249kk8zo      0.0              NaN     NaN
# 175   2c2b8b44b1615ef6d632fb115a85794djmktr      0.0              NaN     NaN
# 236   39b2bdec29461f8a0ae2a5a5b01d259fik8r7      0.0              NaN     NaN
# 262   5c9de1da50cc32a29ffd596ae24cd2be24cly      0.0              NaN     NaN
# 271   1a1d480ca96a50e5fa8af28cf9121d80gx8g2      0.0              NaN     NaN
# 299   458d233d676d8f62406213ab319b8334dbdxh      0.0              NaN     NaN
# 305   81d6c498369ab4af3fea529406dc7d96flle8      0.0              NaN     NaN
# 339   a3d2de7675556553a5f08e4c88d2c2281rrln      0.0              NaN     NaN
# 364   796f3dd849480319c21677833dc1a6c87c6p1      0.0              NaN     NaN
# 620   03a2f817014a39b3e162b5bebc266b38ou4ii      0.0              NaN     NaN
# 633   5924a488253da832477795257e69d4d2pbdwx      0.0              NaN     NaN
# 741   ea349e9643eac4a7bfd988257e7bea33e8zvd      0.0              NaN     NaN
# 750   a3d2de7675556553a5f08e4c88d2c2283li9a      0.0              NaN     NaN
# 773   a3d2de7675556553a5f08e4c88d2c228kiru5      0.0              NaN     NaN
# 808   adfe268fb0ff0bfb337a195a3987f1c1axk7b      0.0              NaN     NaN
# 908   94ffc372dce471cc407d01eb2491950cw4jip      0.0              NaN     NaN
# 997   a3d2de7675556553a5f08e4c88d2c2282rsry      0.0              NaN     NaN
# 1026  ca0287783f4732fe85bea36c0485b3bb1hzax      0.0              NaN     NaN
# 1052  eef1d3edbcdad054cf65255852f8ad9336zui      0.0              NaN     NaN
# 1135  a3d2de7675556553a5f08e4c88d2c228ni64o      0.0              NaN     NaN
# 1149  8b364fa601af02d98e6a142050de9a8fp5n4z      0.0              NaN     NaN
# 1304  f7b3a012d9f0b6931dc0a8dcc9ecc4c5q6r9o      0.0              NaN     NaN
# 1496  b98f270a217ec53294c334d2936eb7f7gsi4l      0.0              NaN     NaN
# 1511  0b697d222013b544c8fe4ce8540c68149pes0      0.0              NaN     NaN
# 1551  aaed475d3674cbb9326ac06ff4fc46f784v20      0.0              NaN     NaN
# 1633  a3d2de7675556553a5f08e4c88d2c22877mou      0.0              NaN     NaN
# 1729  31a7ecb2eedae970ece2ff50761acdeaxwtun      0.0              NaN     NaN
# 1909  3a7e6a32b24aeab0688e91a41f3188e23njk7      0.0              NaN     NaN
#
#       sum_of_diffs  mean_time_diff  id_or_in
# 49             NaN             NaN       NaN
# 88             NaN             NaN       NaN
# 175            NaN             NaN       NaN
# 236            NaN             NaN       NaN
# 262            NaN             NaN       NaN
# 271            NaN             NaN       NaN
# 299            NaN             NaN       NaN
# 305            NaN             NaN       NaN
# 339            NaN             NaN       NaN
# 364            NaN             NaN       NaN
# 620            NaN             NaN       NaN
# 633            NaN             NaN       NaN
# 741            NaN             NaN       NaN
# 750            NaN             NaN       NaN
# 773            NaN             NaN       NaN
# 808            NaN             NaN       NaN
# 908            NaN             NaN       NaN
# 997            NaN             NaN       NaN
# 1026           NaN             NaN       NaN
# 1052           NaN             NaN       NaN
# 1135           NaN             NaN       NaN
# 1149           NaN             NaN       NaN
# 1304           NaN             NaN       NaN
# 1496           NaN             NaN       NaN
# 1511           NaN             NaN       NaN
# 1551           NaN             NaN       NaN
# 1633           NaN             NaN       NaN
# 1729           NaN             NaN       NaN
# 1909           NaN             NaN       NaN

# %% [markdown]
# This replaces the NaN values in the no_of_bids_made column with zero

# %%
training_data.loc[training_data['no_of_bids_made']!=training_data['no_of_bids_made'],'no_of_bids_made']=0

# %% [markdown]
# This changes the NaN values in the id_or_in column to 0

# %%
training_data.loc[training_data['id_or_in']!=training_data['id_or_in'],'id_or_in']=0

# %%
training_data.isnull().sum()
# Out:
# bidder_id            0
# payment_account      0
# address              0
# outcome              0
# no_of_bids_made      0
# country             35
# sum_of_diffs       331
# mean_time_diff     331
# id_or_in             0
# dtype: int64

# %% [markdown]
# This is to find the mean value of the mean_time_diff when the outcome is human in order to substitute NaN when a bidder has made 0 or 1 bid.

# %%
temp=training_data[training_data['outcome']==0].mean_time_diff.sum()/training_data[training_data['outcome']==0].mean_time_diff.count()
training_data.loc[training_data['mean_time_diff']!=training_data['mean_time_diff'],'mean_time_diff']=temp

# %%
training_data.isnull().sum()
# Out:
# bidder_id            0
# payment_account      0
# address              0
# outcome              0
# no_of_bids_made      0
# country             35
# sum_of_diffs       331
# mean_time_diff       0
# id_or_in             0
# dtype: int64

# %% [markdown]
# This is to merge the testing data with the bidder_data

# %%
testing_data=testing_data.merge(bidder_data,how='left',on='bidder_id')

# %%
testing_data.head()
# Out:
#                                bidder_id  \
# 0  49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1  a921612b85a1494456e74c09393ccb65ylp4y
# 2  6b601e72a4d264dab9ace9d7b229b47479v6i
# 3  eaf0ed0afc9689779417274b4791726cn5udi
# 4  cdecd8d02ed8c6037e38042c7745f688mx5sf
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228htx90
# 1  a3d2de7675556553a5f08e4c88d2c228rs17i
# 2  925381cce086b8cc9594eee1c77edf665zjpl
# 3  a3d2de7675556553a5f08e4c88d2c228nclv5
# 4  a3d2de7675556553a5f08e4c88d2c228dtdkd
#
#                                  address  no_of_bids_made country  \
# 0  5d9fa1b71f992e7c7a106ce4b07a0a754le7c              4.0      us
# 1  a3d2de7675556553a5f08e4c88d2c228klidn              3.0      az
# 2  a3d2de7675556553a5f08e4c88d2c228aght0             17.0      id
# 3  b5714de1fd69d4a0d2e39d59e53fe9e15vwat            148.0      bd
# 4  c3b363a3c3b838d58c85acf0fc9964cb4pnfa             23.0      za
#
#    sum_of_diffs  mean_time_diff  id_or_in
# 0  7.022368e+13    1.755592e+13       0.0
# 1  7.600205e+13    2.533402e+13       0.0
# 2  2.910526e+11    1.712074e+10       1.0
# 3  7.652163e+13    5.170381e+11       0.0
# 4  6.574789e+12    2.858604e+11       0.0

# %%
testing_data.isnull().sum()
# Out:
# bidder_id            0
# payment_account      0
# address              0
# no_of_bids_made     70
# country             77
# sum_of_diffs       825
# mean_time_diff     825
# id_or_in            70
# dtype: int64

# %% [markdown]
# This is to replace the NaN values in various columns

# %%
testing_data.loc[testing_data['no_of_bids_made']!=testing_data['no_of_bids_made'],'no_of_bids_made']=0

# %%
testing_data.loc[testing_data['id_or_in']!=testing_data['id_or_in'],'id_or_in']=0

# %%
testing_data.loc[testing_data['mean_time_diff']!=testing_data['mean_time_diff'],'mean_time_diff']=temp

# %%
testing_data.isnull().sum()
# Out:
# bidder_id            0
# payment_account      0
# address              0
# no_of_bids_made      0
# country             77
# sum_of_diffs       825
# mean_time_diff       0
# id_or_in             0
# dtype: int64

# %% [markdown]
# This is to eliminate human outliers with a large number of bids(ie. greater than 50000)

# %%
human_data=training_data[training_data['outcome']==0]
human_data=human_data[human_data['no_of_bids_made']<50000]
bot_data=training_data[training_data['outcome']==1]

# %%
train2=human_data.append(bot_data)

# %% [markdown]
# This is to separate the training data so the model can be fitted.

# %%
xtrain=train2[['no_of_bids_made','mean_time_diff','id_or_in']]
ytrain=train2['outcome']

# %% [markdown]
# This is to slice the testing data to get predictions using the model.

# %%
xtest=testing_data[['no_of_bids_made','mean_time_diff','id_or_in']]

# %% [markdown]
# This is to fit the model. I played around with the n_estimators parameter(ie. the number of trees in the forest) and the best results came from this value.

# %%
rf = RandomForestRegressor(n_estimators = 3000, random_state = 42)
rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=3000, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# This is to make predictions using the model and the test data.

# %%
rf_predictions=rf.predict(xtest)

# %% [markdown]
# On submitting this to kaggle, it gets a score of 0.82714.
# Note:By passing a csv file with only 0.0 outcomes on it, a score of 0.50 was given so my model is able to detect a good portion of the bots and the score (0.82714) is not due to simply detecting humans(ie. 0)
